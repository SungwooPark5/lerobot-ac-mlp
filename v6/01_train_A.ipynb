# %% [markdown]
# # V6 — 01: Train Group A (Baselines + Main)
#
# 8개 모델을 두 Wave로 나눠서 실행 (Wave당 GPU 4개).
#
# | Wave | Tag | Policy              | Notes |
# |------|-----|---------------------|-------|
# | 1    | B1  | ACT                 | baseline |
# | 1    | B2  | ACM                 | baseline |
# | 1    | B3  | ACM2                | baseline |
# | 1    | B4  | ACM3                | baseline |
# | 2    | N1  | ACT+ICPE            | control  |
# | 2    | A3  | ACM3+ICPE           | ICPE ablation |
# | 2    | A4  | ACM3+SSCP           | SSCP inference-only |
# | 2    | P1  | ACM3+ICPE+SSCP      | full model |
#
# Wave 1이 끝난 뒤 Wave 2 셀을 실행하세요.

# %%
import sys, os
from pathlib import Path

GPU_OFFSET = 0  # ← only line to change (Wave 1 → GPU_OFFSET+0..3, Wave 2 → GPU_OFFSET+0..3)

sys.path.insert(0, str(Path(".").resolve()))
import common_v6 as v6

os.environ.setdefault("MUJOCO_GL", "osmesa")
os.environ.setdefault("PYOPENGL_PLATFORM", "osmesa")

TAGS_W1 = ["B1", "B2", "B3", "B4"]
TAGS_W2 = ["N1", "A3", "A4", "P1"]
TAGS_ALL = TAGS_W1 + TAGS_W2

# %%
# 전체 상태 확인
v6.print_training_status(TAGS_ALL)

# %%
# ── Wave 1: B1, B2, B3, B4 ────────────────────────────────────────────────────
print("=== Wave 1: B1, B2, B3, B4 ===")
procs_w1 = v6.launch_training(TAGS_W1, GPU_OFFSET)

print()
print("Monitor:")
for tag in TAGS_W1:
    print(f"  tail -f {v6.get_output_dir(tag) / 'train.log'}")

# %%
# Wave 1 완료 후 실행
print("=== Wave 1 완료 상태 ===")
v6.print_training_status(TAGS_W1)

# %%
# ── Wave 2: N1, A3, A4, P1 ────────────────────────────────────────────────────
print("=== Wave 2: N1, A3, A4, P1 ===")
procs_w2 = v6.launch_training(TAGS_W2, GPU_OFFSET)

print()
print("Monitor:")
for tag in TAGS_W2:
    print(f"  tail -f {v6.get_output_dir(tag) / 'train.log'}")

# %%
# 전체 최종 상태
print("=== Group A 전체 완료 상태 ===")
v6.print_training_status(TAGS_ALL)
